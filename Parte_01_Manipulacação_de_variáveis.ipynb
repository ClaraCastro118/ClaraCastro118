# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaraCastro118/ClaraCastro118/blob/main/Parte_01_Manipulaca%C3%A7%C3%A3o_de_vari%C3%A1veis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Manipulação de Variáveis

# %%
num = -3
num_de_jogos = 14
n_convidados = 30

# %%
num_de_jogos
# Out:
# 14

# %%
num
# Out:
# -3

# %%
print(n_convidados)
# Out:
# 30

# %%
print(n_convidados, num , num_de_jogos)
# Out:
# 30 -3 14

# %%
pi = 3.14
euler = 2.71
escala_terremoto = - 4.55

# %%
print (pi)
print (euler)
print( escala_terremoto)
# Out:
# 3.14
# 2.71
# -4.55

# %% [markdown]
# String e Chars

# %%
letra = "a"
palavra1 = "linguagem de programação"
palavra2 = "pyhton"

# %%
print(letra,palavra1)
# Out:
# a linguagem de programação

# %%
# Estou apreendendo uma linguagem de programação

print("Estou apreendendo uma",palavra1)
# Out:
# Estou apreendendo uma linguagem de programação

# %%
print("Esta", palavra1, "se chama", palavra2)
# Out:
# Esta linguagem de programação se chama pyhton

# %%
palavra3 ="234"

# %%
idade = 15

# %%
idade = input("digite sua idade: ")
# Out:
# digite sua idade: 30

# %%
print(idade)
# Out:
# 10

# %%
print("sua idade é :" , idade)
# Out:
# sua idade é : 30

# %%
ph = input ("qual o ph do solo durante a última medição? ")
# Out:
# qual o ph do solo durante a última medição? 2.5

# %%
print ("O ph medido foi :" , ph )
# Out:
# O ph medido foi : 2.5

# %%
num1 = int(input ("digite o primeiro numero : "))
num2 = int(input("Digite o segundo numero : "))
print ("soma dos numeros é" , num1 + num2)
# Out:
# digite o primeiro numero : 5
# Digite o segundo numero : 2
# soma dos numeros é 7

# %%
x = 8
y = 5

print(x+y)
# Out:
# 13

# %%
print(x-y)
print(y/x)
print(y*x)
# Out:
# 3
# 0.625
# 40

# %%
velocidade_media = float(input("digite a velocidade media: "))
tempo_gasto = float(input("digite o tempo gasto na viagem em horas :"))
distancia_percorrida = float(input("Digite a distancia percorrida em km :"))
listro_utilizado = float(input("digite a quantidade de litros utilizado na viagem : "))
# Out:
# digite a velocidade media: 80
# digite o tempo gasto na viagem em horas :2
# Digite a distancia percorrida em km :140
# digite a quantidade de litros utilizado na viagem : 50

# %%
distancia = tempo_gasto * velocidade_media
litros = distancia_percorrida / 12

# %%
print(velocidade_media,"velocidade")
print(tempo_gasto ,"tempo")
print(distancia_percorrida, "distancia")
print(listro_utilizado ,"litros")
# Out:
# 80.0 velocidade
# 2.0 tempo
# 140.0 distancia
# 50.0 litros

# %% [markdown]
# Manipulção de Strings

# %%
import builtins
a = "casaco"
builtins.print(a)
# Out:
# casaco
