# %% [markdown]
# <a href="https://colab.research.google.com/github/ClaraCastro118/ClaraCastro118/blob/main/aula02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# interpolação

# %%
n1 = float(int(input("Digite um número ")))
n2 = float(int(input("Digite outro número ")))

print(n1,n2)
# Out:
# Digite um número 6
# Digite outro número 7
# 6.0 7.0

# %%
print(n1+ n2)
# Out:
# 13

# %%
palavra01 = "Boa tarde! "
palavra02= "Hoje vamos continuar com python"

# %%
print (palavra01 + palavra02)
# Out:
# Boa tarde! Hoje vamos continuar com python

# %%
#brincando com interpolaçao
#dividindo 6 por 7 o resultado é 6/7

# %%
print("Dividindo " + str (n1) + " por " + str (n2) + " o resultado " +str (n1/n2))
# Out:
# Dividindo 6.0 por 7.0 o resultado 0.8571428571428571

# %%
print(f'dividindo{n1} por {n2} o resultado é {round(n1/n2,2)}')
# Out:
# dividindo6.0 por 7.0 o resultado é 0.86

# %% [markdown]
# operações matematicas

# %%
a = 5
b = 3
print (a,b)
# Out:
# 5 3

# %%
a+b
# Out:
# 8

# %%
print(" A Soma é " , a+b)
# Out:
#  A Soma é  8

# %%
print(" A subtração  é " , a-b)
# Out:
#  A subtração  é  2

# %%
print(" A multipicação é " , a*b)
# Out:
#  A multipicação é  15

# %%
print(" A divisão é " ,round(a/b,2))
# Out:
#  A divisão é  1.67

# %%
print(" o resto da divisão é " , a%b)
# Out:
#  o resto da divisão é  2

# %%
5*5*5*5
# Out:
# 625

# %%
print("5 elevado a 4 é ", 5**4)
# Out:
# 5 elevado a 4 é  625

# %%
#fazendo a raiz quadrada atraves da biblioteca math
import math

# %%
math.sqrt(81)
# Out:
# 9.0

# %% [markdown]
# arredondamento

# %%
casos_doencas = 134
numero_habitantes = 34342

casos_por_habitantes = casos_doencas / numero_habitantes
print(casos_por_habitantes)
# Out:
# 0.0039019276687438124

# %%
round(casos_por_habitantes,3)
# Out:
# 0.004

# %% [markdown]
# operadores logicos e relacionais

# %%
c = True
d = False

# %%
print (c,d)
# Out:
# True False

# %% [markdown]
# operador AND

# %%
# 0 0 = 0 (falso)
# 0 1 = 0 (falso)
# 1 0 = 0 (falso)
# 1 1 = 1 (verdadeiro)

# %%
c and d
# Out:
# False

# %% [markdown]
# OR

# %%
# 0 0 = 0 (falso)
# 0 1 = 1 (verdadeiro)
# 1 0 = 1 (verdadeiro)
# 1 1 = 1 (verdadeiro)

# %%
c or d
# Out:
# True

# %%
c|d
# Out:
# True

# %%
not c
# Out:
# False

# %%
not d
# Out:
# True

# %% [markdown]
# Operadores Relacionais

# %%
5 > 3
# Out:
# True

# %%
5<3
# Out:
# False

# %%
5 == 4
# Out:
# False

# %%
5>=3
# Out:
# True

# %%
5<=3
# Out:
# False

# %%
5 != 3
# Out:
# True

# %% [markdown]
# operadores condicionais
